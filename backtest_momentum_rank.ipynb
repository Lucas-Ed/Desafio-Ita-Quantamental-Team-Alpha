# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)
from collections import OrderedDict


#Numerical operations
import numpy as np
from numpy.linalg import inv

# Import the backtrader platform
import backtrader as bt
import backtrader.analyzers as btanalyzers

#Module to analyze portfolio
import pyfolio as pf
import quantstats as qs

#debugging
from ipdb import set_trace

#ploting
import matplotlib.pyplot as plt

#operating system module
import os

#data analysis module
import pandas as pd

#Datetime library
import datetime as dt

from stochastic_diff_equations import gBm

import math


class GenericCSVData(bt.feeds.GenericCSVData):
    lines = ('adj_close', 'roe', 'roic', 'roa', 'ebit_ev') 
    params = dict(
        adj_close=5,
        volume=6,
        roe=7,
        roic=8,
        roa=9,
        ebit_ev=10,
        dtformat='%Y-%m-%d',  # fix date format a yyyy-mm-dd
        openinterest=-1,  # -1 indicates there is no openinterest field
        
    )


class kelly_criterion():
    def __init__(self):
        pass
    
    def gBm(self, μ:list, σ:list, ρ=0, independent=True):
        self.μ = μ
        self.σ = σ
        N = len(μ)
        A = self.A
        B = self.B
        if independent:
            M = np.array([[A(l) if l==l_ else B(l)*B(l_) for l in range(N)] for l_ in range(N)])
        else:
            Mij = np.exp(μ[0]+μ[1]+ρ*σ[0]*σ[1]) - np.exp(μ[0]) - np.exp(μ[1]) + 1 #s.t. i!=j
            M = np.array([[A(l) if l==l_ else Mij for l in range(N)] for l_ in range(N)])
        b = np.array([B(l) for l in range(N)])
        
        return np.dot(inv(M), b)
    
    def B(self, l):
        μ = self.μ
        return np.exp(μ[l]) - 1
    
    def A(self, l):
        μ = self.μ
        σ = self.σ
        return 1 - 2*np.exp(μ[l]) + np.exp(2*μ[l] + σ[l])
    
class momentumStrat(bt.Strategy):    
    params = dict(
        enableLog=True, 
        gBmSize=2**8+1,
        rebal_monthday=1,
        stocks_in_portfolio=8,
        first_filter='d.roe', 
        second_filter='d.ebit_ev',
        long_only=False)
        #filtros disponiveis: roa, roic, roe, ebit_ev 
        #obs - sempre coloque o "d." para que funcione coretamente no código
    
    def __init__(self):
        
        self.order = None
        

        gBms = [gBm(d, size=self.p.gBmSize) for d in self.datas]
        driftAcoes = [gBm.μ for gBm in gBms]
        volatAcoes = [gBm.σ for gBm in gBms]

        self.driftAcoes = {d:drift for d, drift in zip(self.datas, driftAcoes)}
        self.volatAcoes = {d:volat for d, volat in zip(self.datas, volatAcoes)}

        self.add_timer(
            when=bt.Timer.SESSION_START,
            monthdays=[self.p.rebal_monthday],
            monthcarry=True  # if a day isn't there, execute on the next
        )  
    
    def notify_order(self, order):
        if order.status in [order.Submitted, order.Accepted]:
            # Buy/Sell order submitted/accepted to/by broker - Nothing to do
            return

        # Check if an order has been completed
        # Attention: broker could reject order if not enough cash
        if order.status in [order.Completed]:
            if order.isbuy():
                self.log(
                    'BUY EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                    (order.executed.price,
                     order.executed.value,
                     order.executed.comm))
                
                self.buyprice = order.executed.price
                self.buycomm = order.executed.comm
                
            else:  # Sell
                
                self.log('SELL EXECUTED, Price: %.2f, Cost: %.2f, Comm %.2f' %
                         (order.executed.price,
                          order.executed.value,
                          order.executed.comm))

            self.bar_executed = len(self)
        
        elif order.status==order.Canceled:
            self.log('Order Canceled. Price: {}'.format(order.price))
        elif order.status==order.Margin:
            self.log('Order Margin. Price: {}'.format(order.price))
        elif order.status==order.Rejected:
            self.log('Order Rejected. Price: {}'.format(order.price))

        self.order = None

    def log(self, txt, dt=None, doprint=False):
        ''' Logging function fot this strategy'''
        if self.params.enableLog or doprint:
            dt = dt or self.datas[0].datetime.date(0)
            print('%s, %s' % (dt.isoformat(), txt))
     
    def notify_timer(self, timer, when, *args, **kwargs):
        if  self.order or len(self)<=self.p.gBmSize:
            return
        #if self.datetime.datetime(0) >= dt.datetime.strptime('2018-03-01', format='%Y-%m-%d'):
        #    set_trace()
        
        #creating the formula for the current period
        first_rank = {d._name:eval(self.p.first_filter)[0] for d in self.datas \
            if not math.isnan(eval(self.p.first_filter)[0]) and d.close.get(0, self.p.gBmSize)}

        second_rank = {d._name:eval(self.p.second_filter)[0] for d in self.datas \
            if not math.isnan(eval(self.p.second_filter)[0]) and d.close.get(0, self.p.gBmSize)}


        momentum_rank = {d._name:(self.driftAcoes[d][0]/self.volatAcoes[d][0]) \
            for d in self.datas if d.close.get(0, self.p.gBmSize)}

        #check if there are values
        if not bool(first_rank) or not bool(second_rank) or not momentum_rank:
            return
        
        first_rank = pd.DataFrame(first_rank, index=['first_filter']).T
        second_rank = pd.DataFrame(second_rank, index=['second_filter']).T
        momentum_rank = pd.DataFrame(momentum_rank, index=['momentum_filter']).T
        magic_formula = pd.concat([first_rank, second_rank, momentum_rank], axis=1)
        
        #index | first_filter | second_filter
        #  A   |       a00    |      a01
        #  B   |       a10    |      a11

        magic_formula.dropna(inplace=True)
        magic_formula['first_filter_rank'] = magic_formula['first_filter'].rank(ascending=False, method='first')
        magic_formula['second_filter_rank'] = magic_formula['second_filter'].rank(ascending=False, method='first')
        magic_formula['momentum_rank'] = magic_formula['momentum_filter'].rank(ascending=False, method='first')
        magic_formula['MAGIC_FORMULA_rank'] = magic_formula['first_filter_rank']+\
            magic_formula['second_filter_rank']+magic_formula['momentum_rank']
        
        magic_formula.sort_values('MAGIC_FORMULA_rank', axis=0, inplace=True)


        #selecting top companies with highest rank
        top_ranks = [d for d in self.datas if d._name in magic_formula.index[:self.p.stocks_in_portfolio]]

        #getting companies current parameters (index 0 approach)
        winners_μ = [self.driftAcoes[winner][0] for winner in top_ranks]
        winners_σ = [self.volatAcoes[winner][0] for winner in top_ranks]

        #estimating weights based on kelly criterion for selected stocks
        winners_w = kelly_criterion().gBm(winners_μ, winners_σ)

        #Long only strategy
        if self.p.long_only:
            winners_w = winners_w[winners_w>0]

        #current positions opened in portfolio
        current_positions = [d for d, pos in self.getpositions().items() if pos]

        
        # remove those no longer top ranked
        # do this first to issue sell orders and free cash
        for d in [d for d in current_positions if d not in top_ranks]:
            self.log('Selling: {}'.format(d._name))
            self.order = self.order_target_percent(d, target=0.0)

        
        #separate companies in which we're going to increase position size
        # vs decrease position size
        reduce_pos = []
        increase_pos = []
        for winner,bet_target in zip(top_ranks, winners_w):
            winner_pos_size = self.getposition(winner, self.broker).size
            if winner_pos_size>bet_target:
                reduce_pos.append((winner, bet_target))
            else:
                increase_pos.append((winner, bet_target))
        
        
        for winner, bet_target in reduce_pos:
            self.log('Reducing position: {}'.format(winner._name))
            self.order_target_percent(winner, target=bet_target)
        
        for winner, bet_target in increase_pos:
            self.log('Increasing position: {}'.format(winner._name))
            self.order_target_percent(winner, target=bet_target)
        
        
    def stop(self):
        line1 = 'long_only - {} /---/ stocks_in_portfolio - {} /---/ '.format(self.p.long_only, self.p.stocks_in_portfolio)
        line2 = 'first_filter - {} /---/ second_filter - {}'.format(self.p.first_filter, self.p.second_filter)
        line3 = '\nEnding Value: {}'.format(self.broker.getvalue())
        msg  =  line1+line2+line3
        self.log(msg, doprint=True)
    

def runStrat(start, end):
    cerebro = bt.Cerebro()
    
    #Set cash value
    cerebro.broker.set_cash(100000)
    
    #Set commission model
    cerebro.broker.setcommission(commission=0)
    
    cerebro.broker.set_checksubmit(False)
    

    #Adding data
    start=dt.datetime.strptime(start, '%Y-%m-%d')
    end=dt.datetime.strptime(end, '%Y-%m-%d')

    files = os.listdir('merged data')
    for file in files:
        datapath = 'merged data//'+file
        data = GenericCSVData(
            dataname=datapath,
            fromdate=start,
            todate=end)
        cerebro.adddata(data)
    
    
    
    #Add analyzers
    cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')
    cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='tradeAnalyzer')
    
    #Add Strategy    
    cerebro.addstrategy(momentumStrat)
    
    #Run Algo
    results = cerebro.run(maxcpus=1)

    
    #Plot results
    #cerebro.plot()
    
    return results

def pyfolio_analyze_strat(results, live):
    strat = results[0]
    pyfoliozer = strat.analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()

    benchmark_rets = pd.read_csv('^BVSP.csv', index_col='Date')[['Adj Close']]
    benchmark_rets.rename(columns={'Adj Close':'Benchmark - IBOV'}, inplace=True)
    benchmark_rets = benchmark_rets.pct_change()[1:]
    benchmark_rets = benchmark_rets['Benchmark - IBOV'] #convert dataframe to pandas series
    benchmark_rets.index = pd.to_datetime(benchmark_rets.index)
    benchmark_rets.loc[benchmark_rets.index>=live]
    benchmark_rets.index = benchmark_rets.index.tz_localize("UTC")
    
    pf.create_full_tear_sheet(
        returns=returns,
        positions=positions,
        transactions=transactions,
        live_start_date=live,  # This date is sample specific
        estimate_intraday=False
    )

def qs_analyze_strat(results):
    strat = results[0]
    analyzers = strat.analyzers

    #Get returns with pyfolio
    pyfoliozer = strat.analyzers.getbyname('pyfolio')
    returns, positions, transactions, gross_lev = pyfoliozer.get_pf_items()
    returns.index = pd.to_datetime(returns.index.astype(str).str[:10])

    #Create report with quantstats
    qs.reports.full(returns, '^BVSP')

    #Get more analytics insight about strategy
    tradeAnalyzer = analyzers.tradeAnalyzer.get_analysis()
    average_holding = int(tradeAnalyzer['len']['average'])
    average_win_holding = int(tradeAnalyzer['len']['won']['average'])
    average_loss_holding = int(tradeAnalyzer['len']['lost']['average'])

    
    print('Average Holding: {}'.format(average_holding))
    print('Average Win Holding: {}'.format(average_win_holding))
    print('Average Loss Holding: {}'.format(average_loss_holding))

if __name__=='__main__':
    live = '2018-01-01'
    #'2018-03-01'
    #'2009-01-01'
    r = runStrat('2009-01-03', '2020-12-31')
    qs_analyze_strat(r)
# Out:
# 2020-12-30, Increasing position: GGBR4
# 2020-12-30, Increasing position: GOAU4
# 2020-12-30, Increasing position: USIM5
# 2020-12-30, BUY EXECUTED, Price: 26.45, Cost: 7644.05, Comm 0.00
# 2020-12-30, BUY EXECUTED, Price: 32.24, Cost: 6512.48, Comm 0.00
# 2020-12-30, BUY EXECUTED, Price: 103.35, Cost: 9405.19, Comm 0.00
# 2020-12-30, Reducing position: GGBR4
# 2020-12-30, Reducing position
# 2013-06-04, BUY EXECUTED, Price: 12.74, Cost: 2038.40, Comm 0.00
# 2013-06-04, Order Margin. Price: 12.79
# 2013-06-04, Order Margin. Price: 12.79
# 2013-06-04, Order Margin. Price: 12.79
# 2013-06-04, Order Margin. Price: 12.79
# 2013-07-01, Reducing position: BRFS3
# 2013-07-01, Reducing position: CSAN3
# 2013-07-01, Reducing position: LAME4
# 2013-07-01, Reducing position: PETR3
# 2013-07-01, Increasing position: ECOR3
# 2013-07-01, Increasing position: MULT3
# 2013-07-01, Increasing position: PETR4
# 2013-07-01, Increasing position: SUZB3
# 2013-07-02, Order Margin. Price: 48.19
# 2013-07-02, SELL EXECUTED, Price: 43.01, Cost: 1879.73, Comm 0.00
# 2013-07-02, SELL EXECUTED, Price: 11.37, Cost: 2099.76, Comm 0.00
# 2013-07-02, SELL EXECUTED, Price: 11.37, Cost: 2104.23, Comm 0.00
# 2013-07-02, Order Margin. Price: 11.52
# 2013-07-02, Order Margin. Price: 11.52
# 2013-07-02, Order Margin. Price: 11.52
# 2013-07-02, Order Margin. Price: 11.52
# 2013-08-01, Reducing position: BRFS3
# 2013-08-01, Reducing position: CSAN3
# 2013-08-01, Reducing position: LAME4
# 2013-08-01, Reducing position: PETR3
# 2013-08-01, Increasing position: ECOR3
# 2013-08-01, Increasing position: MULT3
# 2013-08-01, Increasing position: PETR4
# 2013-08-01, Increasing position: SUZB3
# 2013-08-02, Order Margin. Price: 49.68
# 2013-08-02, BUY EXECUTED, Price: 43.38, Cost: 867.60, Comm 0.00
# 2013-08-02, SELL EXECUTED, Price: 11.85, Cost: 422.36, Comm 0.00
# 2013-08-02, SELL EXECUTED, Price: 11.85, Cost: 423.26, Comm 0.00
# 2013-08-02, Order Margin. Price: 11.81
# 2013-08-02, Order Margin. Price: 11.81
# 2013-08-02, Order Margin. Price: 11.81
# 2013-08-02, Order Margin. Price: 11.81
# 2013-09-02, Reducing position: BRFS3
# 2013-09-02, Reducing position: CSAN3
# 2013-09-02, Reducing position: PETR3
# 2013-09-02, Increasing position: AMER3
# 2013-09-02, Increasing position: BRKM5
# 2013-09-02, Increasing position: JBSS3
# 2013-09-02, Increasing position: UGPA3
# 2013-09-02, Increasing position: VALE3
# 2013-09-03, Order Margin. Price: 55.66
# 2013-09-03, SELL EXECUTED, Price: 42.04, Cost: 2324.52, Comm 0.00
# 2013-09-03, SELL EXECUTED, Price: 11.19, Cost: 4220.55, Comm 0.00
# 2013-09-03, BUY EXECUTED, Price: 14.55, Cost: 6605.70, Comm 0.00
# 2013-09-03, BUY EXECUTED, Price: 18.00, Cost: 3474.00, Comm 0.00
# 2013-09-03, Order Margin. Price: 7.25
# 2013-09-03, Order Margin. Price: 53.7
# 2013-10-01, Selling: BRKM5
# 2013-10-01, Reducing position: AMER3
# 2013-10-01, Reducing position: BRFS3
# 2013-10-01, Reducing position: CSAN3
# 2013-10-01, Reducing position: LAME4
# 2013-10-01, Reducing position: PETR3
# 2013-10-01, Increasing position: JBSS3
# 2013-10-01, Increasing position: PETR4
# 2013-10-01, Increasing position: UGPA3
# 2013-10-02, SELL EXECUTED, Price: 17.82, Cost: 3474.00, Comm 0.00
# 2013-10-02, SELL EXECUTED, Price: 14.50, Cost: 2138.85, Comm 0.00
# 2013-10-02, BUY EXECUTED, Price: 54.88, Cost: 4225.76, Comm 0.00
# 2013-10-02, SELL EXECUTED, Price: 44.00, Cost: 1412.94, Comm 0.00
# 2013-10-02, SELL EXECUTED, Price: 11.76, Cost: 4102.97, Comm 0.00
# 2013-10-02, BUY EXECUTED, Price: 11.76, Cost: 94.08, Comm 0.00
# 2013-10-02, BUY EXECUTED, Price: 7.68, Cost: 3763.20, Comm 0.00
# 2013-10-02, BUY EXECUTED, Price: 11.76, Cost: 2022.72, Comm 0.00
# 2013-10-02, Order Margin. Price: 57.09
# 2013-11-01, Reducing position: AMER3
# 2013-11-01, Reducing position: BRFS3
# 2013-11-01, Reducing position: CSAN3
# 2013-11-01, Reducing position: JBSS3
# 2013-11-01, Reducing position: LAME4
# 2013-11-01, Reducing position: PETR3
# 2013-11-01, Increasing position: BRKM5
# 2013-11-01, Increasing position: UGPA3
# 2013-11-04, BUY EXECUTED, Price: 16.40, Cost: 98.40, Comm 0.00
# 2013-11-04, SELL EXECUTED, Price: 51.82, Cost: 674.60, Comm 0.00
# 2013-11-04, SELL EXECUTED, Price: 44.65, Cost: 91.16, Comm 0.00
# 2013-11-04, SELL EXECUTED, Price: 8.11, Cost: 1067.52, Comm 0.00
# 2013-11-04, SELL EXECUTED, Price: 12.23, Cost: 12.07, Comm 0.00
# 2013-11-04, Order Margin. Price: 19.73
# 2013-11-04, Order Margin. Price: 59.92
# 2013-12-02, Selling: AMER3
# 2013-12-02, Reducing position: BRFS3
# 2013-12-02, Reducing position: CSAN3
# 2013-12-02, Reducing position: JBSS3
# 2013-12-02, Reducing position: PETR3
# 2013-12-02, Increasing position: BRKM5
# 2013-12-02, Increasing position: COGN3
# 2013-12-02, Increasing position: CSNA3
# 2013-12-02, Increasing position: UGPA3
# 2013-12-03, SELL EXECUTED, Price: 13.23, Cost: 4565.25, Comm 0.00
# 2013-12-03, SELL EXECUTED, Price: 50.86, Cost: 481.85, Comm 0.00
# 2013-12-03, SELL EXECUTED, Price: 41.71, Cost: 1686.42, Comm 0.00
# 2013-12-03, BUY EXECUTED, Price: 8.24, Cost: 1886.96, Comm 0.00
# 2013-12-03, SELL EXECUTED, Price: 11.94, Cost: 410.64, Comm 0.00
# 2013-12-03, BUY EXECUTED, Price: 20.78, Cost: 8083.42, Comm 0.00
# 2013-12-03, Order Margin. Price: 39.2
# 2013-12-03, Order Margin. Price: 11.96
# 2013-12-03, Order Margin. Price: 57.0
# 2014-01-02, Selling: ELET3
# 2014-01-02, Selling: ELET6
# 2014-01-02, Selling: EMBR3
# 2014-01-02, Selling: HYPE3
# 2014-01-02, Selling: KLBN11
# 2014-01-02, Selling: LAME4
# 2014-01-02, Selling: PCAR3
# 2014-05-05, BUY EXECUTED, Price: 8.95, Cost: 581.75, Comm 0.00
# 2014-05-05, SELL EXECUTED, Price: 14.00, Cost: -249.20, Comm 0.00
# 2014-05-05, BUY EXECUTED, Price: 7.95, Cost: 930.15, Comm 0.00
# 2014-05-05, SELL EXECUTED, Price: 56.80, Cost: 888.88, Comm 0.00
# 2014-05-05, SELL EXECUTED, Price: 9.15, Cost: 885.25, Comm 0.00
# 2014-06-02, Reducing position: BRFS3
# 2014-06-02, Reducing position: COGN3
# 2014-06-02, Reducing position: CSNA3
# 2014-06-02, Reducing position: JBSS3
# 2014-06-02, Reducing position: UGPA3
# 2014-06-02, Increasing position: CCRO3
# 2014-06-02, Increasing position: GGBR4
# 2014-06-02, Increasing position: USIM5
# 2014-06-03, SELL EXECUTED, Price: 48.99, Cost: 1897.52, Comm 0.00
# 2014-06-03, SELL EXECUTED, Price: 56.77, Cost: 973.79, Comm 0.00
# 2014-06-03, BUY EXECUTED, Price: 8.71, Cost: 1498.12, Comm 0.00
# 2014-06-03, SELL EXECUTED, Price: 7.51, Cost: 1592.66, Comm 0.00
# 2014-06-03, SELL EXECUTED, Price: 53.35, Cost: 1122.13, Comm 0.00
# 2014-06-03, SELL EXECUTED, Price: 17.60, Cost: -739.20, Comm 0.00
# 2014-06-03, BUY EXECUTED, Price: 13.41, Cost: -268.52, Comm 0.00
# 2014-06-03, BUY EXECUTED, Price: 8.04, Cost: -32.15, Comm 0.00
# 2014-07-01, Selling: USIM5
# 2014-07-01, Reducing position: ABEV3
# 2014-07-01, Reducing position: COGN3
# 2014-07-01, Reducing position: CSNA3
# 2014-07-01, Reducing position: GGBR4
# 2014-07-01, Reducing position: JBSS3
# 2014-07-01, Increasing position: BRFS3
# 2014-07-01, Increasing position: CCRO3
# 2014-07-01, Increasing position: UGPA3
# 2014-07-02, SELL EXECUTED, Price: 7.85, Cost: 233.30, Comm 0.00
# 2014-07-02, SELL EXECUTED, Price: 15.99, Cost: -975.39, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 62.11, Cost: 745.32, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 9.29, Cost: 1189.12, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 13.00, Cost: 481.00, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 7.55, Cost: 1351.45, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 18.08, Cost: -1358.89, Comm 0.00
# 2014-07-02, BUY EXECUTED, Price: 51.59, Cost: 919.82, Comm 0.00
# 2014-07-07, BUY EXECUTED, Price: 54.41, Cost: 3329.85, Comm 0.00
# 2014-08-01, Selling: UGPA3
# 2014-08-01, Reducing position: BRFS3
# 2014-08-01, Reducing position: CCRO3
# 2014-08-01, Reducing position: COGN3
# 2014-08-01, Reducing position: CSNA3
# 2014-08-01, Reducing position: GGBR4
# 2014-08-01, Reducing position: JBSS3
# 2014-08-01, Increasing position: ABEV3
# 2014-08-01, Increasing position: USIM5
# 2014-08-04, SELL EXECUTED, Price: 51.42, Cost: 1186.57, Comm 0.00
# 2014-08-04, SELL EXECUTED, Price: 57.25, Cost: 217.64, Comm 0.00
# 2014-08-04, BUY EXECUTED, Price: 17.78, Cost: 764.54, Comm 0.00
# 2014-08-04, BUY EXECUTED, Price: 62.00, Cost: 558.00, Comm 0.00
# 2014-08-04, BUY EXECUTED, Price: 11.69, Cost: 1753.50, Comm 0.00
# 2014-08-04, SELL EXECUTED, Price: 13.19, Cost: 500.71, Comm 0.00
# 2014-08-04, SELL EXECUTED, Price: 8.88, Cost: 255.36, Comm 0.00
# 2014-08-04, BUY EXECUTED, Price: 15.68, Cost: -335.79, Comm 0.00
# 2014-08-04, BUY EXECUTED, Price: 8.28, Cost: 1539.88, Comm 0.00
# 2014-09-01, Selling: ABEV3
# 2014-09-01, Selling: GGBR4
# 2014-09-01, Selling: USIM5
# 2014-09-01, Reducing position: BRFS3
# 2014-09-01, Reducing position: CCRO3
# 2014-09-01, Reducing position: COGN3
# 2014-09-01, Reducing position: CSNA3
# 2014-09-01, Reducing position: JBSS3
# 2014-09-01, Increasing position: CSAN3
# 2014-09-01, Increasing position: EQTL3
# 2014-09-01, Increasing position: UGPA3
# 2014-09-02, BUY EXECUTED, Price: 16.05, Cost: -639.60, Comm 0.00
# 2014-09-02, SELL EXECUTED, Price: 12.72, Cost: 355.77, Comm 0.00
# 2014-09-02, SELL EXECUTED, Price: 8.24, Cost: 1539.88, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 59.00, Cost: 472.00, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 20.61, Cost: 2205.27, Comm 0.00
# 2014-09-02, SELL EXECUTED, Price: 66.71, Cost: 150.55, Comm 0.00
# 2014-09-02, SELL EXECUTED, Price: 9.69, Cost: 3052.05, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 10.10, Cost: 989.80, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 44.90, Cost: 3008.30, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 26.48, Cost: 7679.20, Comm 0.00
# 2014-09-02, BUY EXECUTED, Price: 56.28, Cost: 2476.32, Comm 0.00
# 2014-10-01, Selling: COGN3
# 2014-10-01, Selling: UGPA3
# 2014-10-01, Reducing position: ABEV3
# 2014-10-01, Reducing position: BRFS3
# 2014-10-01, Reducing position: CCRO3
# 2014-10-01, Reducing position: CSAN3
# 2014-10-01, Reducing position: CSNA3
# 2014-10-01, Reducing position: EQTL3
# 2014-10-01, Reducing position: JBSS3
# 2014-10-01, Increasing position: VIVT3
# 2014-10-02, SELL EXECUTED, Price: 15.04, Cost: 9283.92, Comm 0.00
# 2014-10-02, SELL EXECUTED, Price: 50.08, Cost: 2476.32, Comm 0.00
# 2014-10-02, SELL EXECUTED, Price: 15.55, Cost: -746.40, Comm 0.00
# 2014-10-02, SELL EXECUTED, Price: 58.75, Cost: 3242.53, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 39.62, Cost: 335.72, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 88.62, Cost: 546.39, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 65.78, Cost: 843.10, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 91.05, Cost: 301.47, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 19.36, Cost: 622.80, Comm 0.00
# 2020-10-02, SELL EXECUTED, Price: 58.61, Cost: 800.87, Comm 0.00
# 2020-10-02, BUY EXECUTED, Price: 46.98, Cost: 5308.74, Comm 0.00
# 2020-10-02, BUY EXECUTED, Price: 20.58, Cost: 3951.36, Comm 0.00
# 2020-11-03, Selling: UGPA3
# 2020-11-03, Reducing position: ALPA4
# 2020-11-03, Reducing position: AMER3
# 2020-11-03, Reducing position: ENEV3
# 2020-11-03, Reducing position: GGBR4
# 2020-11-03, Reducing position: GNDI3
# 2020-11-03, Reducing position: MGLU3
# 2020-11-03, Reducing position: VALE3
# 2020-11-03, Increasing position: CSNA3
# 2020-11-04, SELL EXECUTED, Price: 16.79, Cost: 1847.64, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 40.55, Cost: 549.36, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 77.60, Cost: 1170.84, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 55.93, Cost: 1127.52, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 23.37, Cost: 288.12, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 68.03, Cost: 665.60, Comm 0.00
# 2020-11-04, SELL EXECUTED, Price: 25.40, Cost: 678.30, Comm 0.00
# 2020-11-04, BUY EXECUTED, Price: 63.28, Cost: 126.56, Comm 0.00
# 2020-11-04, BUY EXECUTED, Price: 22.54, Cost: 3674.02, Comm 0.00
# 2020-12-01, Selling: ENEV3
# 2020-12-01, Reducing position: ALPA4
# 2020-12-01, Reducing position: AMER3
# 2020-12-01, Reducing position: CSNA3
# 2020-12-01, Reducing position: GGBR4
# 2020-12-01, Reducing position: GNDI3
# 2020-12-01, Reducing position: MGLU3
# 2020-12-01, Reducing position: VALE3
# 2020-12-01, Increasing position: UGPA3
# 2020-12-02, SELL EXECUTED, Price: 59.34, Cost: 4181.22, Comm 0.00
# 2020-12-02, SELL EXECUTED, Price: 38.77, Cost: 61.04, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 24.10, Cost: 1108.60, Comm 0.00
# 2020-12-02, SELL EXECUTED, Price: 23.80, Cost: 596.82, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 70.06, Cost: 770.66, Comm 0.00
# 2020-12-02, SELL EXECUTED, Price: 22.88, Cost: 226.10, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 80.90, Cost: 728.10, Comm 0.00
# 2020-12-02, BUY EXECUTED, Price: 21.23, Cost: 1379.95, Comm 0.00
# 2020-12-30, long_only - False /---/ stocks_in_portfolio - 8 /---/ first_filter - d.roe /---/ second_filter - d.ebit_ev
# Ending Value: 65914.30090000006
# <h4>Performance Metrics</h4>
#                            Strategy    Benchmark
# -------------------------  ----------  -----------
# Start Period               2009-01-05  2009-01-05
# End Period                 2020-12-30  2020-12-30
# Risk-Free Rate             0.0%        0.0%
# Time in Market             91.0%       100.0%
#
# Cumulative Return          -31.02%     196.46%
# CAGR﹪                     -3.05%      9.49%
#
# Sharpe                     -0.1        0.49
# Smart Sharpe               -0.09       0.44
# Sortino                    -0.13       0.69
# Smart Sortino              -0.11       0.62
# Sortino/√2                 -0.09       0.49
# Smart Sortino/√2           -0.08       0.44
# Omega                      0.98        0.98
#
# Max Drawdown               -45.91%     -48.63%
# Longest DD Days            3918        2497
# Volatility (ann.)          16.96%      25.72%
# R^2                        0.29        0.29
# Calmar                     -0.07       0.2
# Skew                       -2.55       -0.46
# Kurtosis                   36.42       9.4
#
# Expected Daily %           -0.01%      0.04%
# Expected Monthly %         -0.26%      0.76%
# Expected Yearly %          -3.05%      9.48%
# Kelly Criterion            1.79%       3.32%
# Risk of Ruin               0.0%        0.0%
# Daily Value-at-Risk        -1.76%      -2.62%
# Expected Shortfall (cVaR)  -1.76%      -2.62%
#
# Gain/Pain Ratio            -0.02       0.09
# Gain/Pain (1M)             -0.09       0.52
#
# Payoff Ratio               0.98        1.0
# Profit Factor              0.98        1.09
# Common Sense Ratio         0.98        1.12
# CPC Index                  0.49        0.56
# Tail Ratio                 1.0         1.03
# Outlier Win Ratio          6.41        2.9
# Outlier Loss Ratio         4.83        2.88
#
# MTD                        5.69%       9.57%
# 3M                         1.51%       26.03%
# 6M                         -2.41%      24.62%
# YTD                        -12.14%     2.88%
# 1Y                         -12.14%     2.88%
# 3Y (ann.)                  -1.8%       16.05%
# 5Y (ann.)                  1.33%       22.48%
# 10Y (ann.)                 -3.13%      5.58%
# All-time (ann.)            -3.05%      9.49%
#
# Best Day                   10.19%      13.91%
# Worst Day                  -13.87%     -14.78%
# Best Month                 16.06%      16.97%
# Worst Month                -23.07%     -29.9%
# Best Year                  13.84%      70.43%
# Worst Year                 -18.02%     -18.11%
#
# Avg. Drawdown              -8.36%      -4.68%
# Avg. Drawdown Days         660         62
# Recovery Factor            -0.68       4.04
# Ulcer Index                0.28        0.2
# Serenity Index             -0.03       0.45
#
# Avg. Up Month              2.6%        5.72%
# Avg. Down Month            -3.78%      -5.13%
# Win Days %                 51.5%       51.61%
# Win Month %                55.73%      54.86%
# Win Quarter %              56.82%      64.58%
# Win Year %                 45.45%      66.67%
# Beta                       0.35        -
# Alpha                      -0.06       -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2010-04-09  2020-03-18  2020-12-30  3918    -45.905139        -40.034168
# 2  2010-02-03  2010-02-08  2010-02-26    23     -1.955184         -1.657676
# 3  2010-03-17  2010-03-25  2010-03-29    12     -0.963053         -0.915372
# 4  2010-03-11  2010-03-15  2010-03-16     5     -0.646334         -0.525590
# 5  2010-04-07  2010-04-07  2010-04-08     1     -0.405451          0.000000
# <h4>Strategy Visualization</h4>
# Average Holding: 103
# Average Win Holding: 120
# Average Loss Holding: 92
